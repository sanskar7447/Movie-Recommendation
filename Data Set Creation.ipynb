# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
data1 = pd.read_csv('movie_metadata.csv')

# %%
data1.shape
# Out:
# (5043, 28)

# %%
data1 = data1.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
data1.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker                   NaN
#
#                             genres  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary
#
#                                                movie_title
# 0                                                  Avatar
# 1                Pirates of the Caribbean: At World's End
# 2                                                 Spectre
# ...

# %%
data1['actor_1_name'] = data1['actor_1_name'].replace(np.nan, '')
data1['actor_2_name'] = data1['actor_2_name'].replace(np.nan, '')
data1['actor_3_name'] = data1['actor_3_name'].replace(np.nan, '')
data1['director_name'] = data1['director_name'].replace(np.nan, '')

# %%
data1['genres'] = data1['genres'].str.replace('|', ' ')

# %%
data1['movie_title'] = data1['movie_title'].str.lower()

# %%
data1['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end\xa0"

# %%
# removing the null terminating char at the end
data1['movie_title'] = data1['movie_title'].apply(lambda x : x[:-1])

# %%
data1['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end"

# %%
data1.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                               movie_title
# 0                                                  avatar
# 1                pirates of the caribbean: at world's end
# 2                                                 spectre
# 3                                   the dark knight rises
# ...

# %%
data1['comb'] = data1['actor_1_name'] + ' ' + data1['actor_2_name'] + ' '+ data1['actor_3_name'] + ' '+ data1['director_name'] +' ' + data1['genres']

# %%
data1
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039                         Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
credits = pd.read_csv('credits.csv')

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
meta = pd.read_csv('movies_metadata.csv')

# %%
meta
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce')

# %%
meta['year'] = meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
new_meta = meta.loc[meta.year == 2017,['genres','id','title','year']]
new_meta
# Out:
#                                                   genres      id  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  166426
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  141052
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284053
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  283995
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  245842
# ...                                                  ...     ...
# 45398  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  468707
# 45417  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...  461297
# 45437  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  455661
# 45453  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...  404604
# 45465                                                 []  461257
#
#                                                   title    year
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# ...

# %%
new_meta['id'] = new_meta['id'].astype(int)
data = pd.merge(new_meta, credits, on='id')

# %%
pd.set_option('display.max_colwidth', 100)
data.head()
# Out:
#                                                                                                 genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}, {...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'...
# 4       [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}]
#
#        id                                             title    year  \
# 0  166426  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 1  141052                                    Justice League  2017.0
# 2  284053                                    Thor: Ragnarok  2017.0
# 3  283995                    Guardians of the Galaxy Vol. 2  2017.0
# ...

# %%
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: object

# %%
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie
# Out:
#                       director_name          actor_1_name    actor_2_name  \
# 0    Joachim Rønning Espen Sandberg           Johnny Depp   Javier Bardem
# 1                       Zack Snyder           Ben Affleck    Henry Cavill
# 2                     Taika Waititi       Chris Hemsworth  Tom Hiddleston
# 3                        James Gunn           Chris Pratt     Zoe Saldana
# 4                     Sean McNamara        Pierce Brosnan    William Hurt
# ..                              ...                   ...             ...
# 526                Hannaleena Hauru        Inka Haapamäki   Rosa Honkonen
# 527           Jonathan A. Rosenbaum  Lou Diamond Phillips   Wallace Shawn
# 528        Beth David Esteban Bravo                   NaN             NaN
# 529                    Ravi Udyawar        Sridevi Kapoor       Sajal Ali
# 530                   Daisy Asquith                   NaN             NaN
#
#         actor_3_name                      genres_list  \
# ...

# %%
movie.isna().sum()
# Out:
# director_name     4
# actor_1_name     22
# actor_2_name     55
# actor_3_name     70
# genres_list       7
# title             0
# dtype: int64

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

# %%
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
movie = movie.replace(np.nan, '', regex=True)

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie
# Out:
#                       director_name          actor_1_name    actor_2_name  \
# 0    Joachim Rønning Espen Sandberg           Johnny Depp   Javier Bardem
# 1                       Zack Snyder           Ben Affleck    Henry Cavill
# 2                     Taika Waititi       Chris Hemsworth  Tom Hiddleston
# 3                        James Gunn           Chris Pratt     Zoe Saldana
# 4                     Sean McNamara        Pierce Brosnan    William Hurt
# ..                              ...                   ...             ...
# 526                Hannaleena Hauru        Inka Haapamäki   Rosa Honkonen
# 527           Jonathan A. Rosenbaum  Lou Diamond Phillips   Wallace Shawn
# 528        Beth David Esteban Bravo
# 529                    Ravi Udyawar        Sridevi Kapoor       Sajal Ali
# 530                   Daisy Asquith
#
#         actor_3_name                           genres  \
# 0      Geoffrey Rush  Adventure Action Fantasy Comedy
# ...

# %% [markdown]
# # Extracting features of 2018 , 2019 and 2020 movies from Wikipedia

# %%
link1 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1_1 = pd.read_html(link1, header=0)[2]
df2_1 = pd.read_html(link1, header=0)[3]
df3_1 = pd.read_html(link1, header=0)[4]
df4_1 = pd.read_html(link1, header=0)[5]

link2 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1_2 = pd.read_html(link2, header=0)[2]
df2_2 = pd.read_html(link2, header=0)[3]
df3_2 = pd.read_html(link2, header=0)[4]
df4_2 = pd.read_html(link2, header=0)[5]

link3 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1_3 = pd.read_html(link3, header=0)[3]
df2_3 = pd.read_html(link3, header=0)[4]
df3_3 = pd.read_html(link3, header=0)[5]
df4_3 = pd.read_html(link3, header=0)[6]

# %%
df1 = df1_1.append(df2_1.append(df3_1.append(df4_1,ignore_index=True),ignore_index=True),ignore_index=True)
df1
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                              Production company  \
# 0    Universal Pictures / Blumhouse Productions / Stage 6 Films
# 1                                        Vertical Entertainment
# 2                                             Momentum Pictures
# 3                                          Samuel Goldwyn Films
# ...

# %%
df2 = df1_2.append(df2_2.append(df3_2.append(df4_2,ignore_index=True),ignore_index=True),ignore_index=True)
df2
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                                Production company  \
# 0                                               Columbia Pictures
# 1                                                       IFC Films
# 2                                     Hangman Justice Productions
# 3                                               Columbia Pictures
# 4                                               STX Entertainment
# ...

# %%
df3 = df1_3.append(df2_3.append(df3_3.append(df4_3,ignore_index=True),ignore_index=True),ignore_index=True)
df3['Title'][126] = 'The SpongeBob Movie: Sponge on the Run'
df3
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 267  DECEMBER         25       We Can Be Heroes
# 268  DECEMBER         25      News of the World
# 269  DECEMBER         25  One Night in Miami...
# 270  DECEMBER         25  Promising Young Woman
# 271  DECEMBER         30      Pieces of a Woman
#
#                                                Production company  \
# 0              Screen Gems / Stage 6 Films / Ghost House Pictures
# 1    20th Century Fox / TSG Entertainment / Chernin Entertainment
# 2                                              Paramount Pictures
# 3                                                       IFC Films
# ...

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'fa5b49d630648f7a09d47448dc2d370d'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df1['genres'] = df1['Title'].map(lambda x: get_genre(str(x)))

# %%
df1
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                              Production company  \
# 0    Universal Pictures / Blumhouse Productions / Stage 6 Films
# 1                                        Vertical Entertainment
# 2                                             Momentum Pictures
# 3                                          Samuel Goldwyn Films
# ...

# %%
df2['genres'] = df2['Title'].map(lambda x: get_genre(str(x)))

# %%
df3['genres'] = df3['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2018 = df1[['Title','Cast and crew','genres']]
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                                                                            Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, ...
# 1    Lauren Wolkstein (director); Christopher Radcliff (co-director/screenplay); Alex Pettyfer, James...
# 2    Simon West (director); Duncan Falconer, Warren Davis II (screenplay); Dominic Cooper, Austin Sto...
# 3       Warwick Thornton (director); David Tranter, Steven McGregor (screenplay); Bryan Brown, Sam Neill
# ...

# %%
df_2019 = df2[['Title','Cast and crew','genres']]
df_2020 = df3[['Title','Cast and crew','genres']]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                                                                            Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, ...
# 1    Lauren Wolkstein (director); Christopher Radcliff (co-director/screenplay); Alex Pettyfer, James...
# 2    Simon West (director); Duncan Falconer, Warren Davis II (screenplay); Dominic Cooper, Austin Sto...
# 3       Warwick Thornton (director); David Tranter, Steven McGregor (screenplay); Bryan Brown, Sam Neill
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18=new_df18.replace(np.nan, '', regex=True)
new_df18['movie_title'] = new_df18['movie_title'].str.lower()
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
new_df19=new_df19.replace(np.nan, '', regex=True)
new_df19['movie_title'] = new_df19['movie_title'].str.lower()
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 237  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 238            Greta Gerwig        Saoirse Ronan           Emma Watson
# 239              Sam Mendes        George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# ...

# %%
new_df20=new_df20.replace(np.nan, '', regex=True)
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 267  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 268   Paul Greengrass              Tom Hanks      Helena Zengel
# 269       Regina King      Kingsley Ben-Adir          Eli Goree
# 270   Emerald Fennell         Carey Mulligan         Bo Burnham
# 271  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# ...

# %%
movie
# Out:
#                       director_name          actor_1_name    actor_2_name  \
# 0    Joachim Rønning Espen Sandberg           Johnny Depp   Javier Bardem
# 1                       Zack Snyder           Ben Affleck    Henry Cavill
# 2                     Taika Waititi       Chris Hemsworth  Tom Hiddleston
# 3                        James Gunn           Chris Pratt     Zoe Saldana
# 4                     Sean McNamara        Pierce Brosnan    William Hurt
# ..                              ...                   ...             ...
# 526                Hannaleena Hauru        Inka Haapamäki   Rosa Honkonen
# 527           Jonathan A. Rosenbaum  Lou Diamond Phillips   Wallace Shawn
# 528        Beth David Esteban Bravo
# 529                    Ravi Udyawar        Sridevi Kapoor       Sajal Ali
# 530                   Daisy Asquith
#
#         actor_3_name                           genres  \
# 0      Geoffrey Rush  Adventure Action Fantasy Comedy
# ...

# %%
final = data1.append(movie.append(new_df18.append(new_df19.append(new_df20,ignore_index=True),ignore_index=True),ignore_index=True))

# %%
final
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 1309   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 1310    Paul Greengrass              Tom Hanks     Helena Zengel
# 1311        Regina King      Kingsley Ben-Adir         Eli Goree
# 1312    Emerald Fennell         Carey Mulligan        Bo Burnham
# 1313   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
final.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final.to_csv('final_data.csv',index=False)
